# %% [markdown]
# # Prepate Data Folder Structure for YOLO format

# %%
import base64
from email.mime import image
from idna import encode
from openai import OpenAI
import pandas as pd
import time
annotations_path = "gt_for_classification_multiclass_from_filenames_0_index.csv"
df =pd.read_csv(annotations_path)

df["answers"] = ""
client = OpenAI(api_key="")

def encode_image(path):
    with open(path, "rb") as f:
        return base64.b64encode(f.read()).decode("utf-8")
    

image_path = "images\\b00_i01_a00_20240813_152043_left_0001.jpg"
image_base64 = encode_image(image_path)
def talk_to_gpt4_image(image_base64):
    prompt = """
    Draw a bounding box around the medical instrument in the image and return only the coordinates of the box in the format (x1, y1, x2, y2).
    """

    response = client.chat.completions.create(
        model="gpt-5.2",
        messages=[
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": prompt},
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"data:image/jpeg;base64,{image_base64}"
                        },
                    },
                ],
            }
        ],
        max_completion_tokens=500,
    )
    return response.choices[0].message.content

#function that uses chatpgt 5.2 to annotate instruments in images
recalculate_positions = False
if recalculate_positions:
    for data in df.itertuples():
        if data.category_id != 0:
            print(f"Processing {data.file_name}")
            image_base64 = encode_image("images\\" + data.file_name)
            answer = talk_to_gpt4_image(image_base64)
            print(f"Processed {data.file_name}: {answer}")
            df.at[data.Index, "answers"] = answer
            # To avoid rate limiting

# %%
import huggingface_hub as hf
hf.login(token ="")

# %%
with open("../test/train.txt", "r") as f:
    for line in f:

        parts = line.split("/")  # or "/" depending on file content

        try:
            with open("../test/labels/train/" + str(parts[-1])[:-5]+".txt", "r") as img_file:
                bbox=[]
                label=[]
                for line in img_file:
                    print(line)
                    parts = line.split(" ")
                    label.append(int(parts[0]))              # class id 
                    bbox.append(list(map(float, parts[1:])))
        except Exception as e:
            bbox=[]
            label=[]
        print(parts[-1][:-1], bbox, label)

# %%
import torch
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
#################################### For Image ####################################
from PIL import Image
from sam3.model_builder import build_sam3_image_model
from sam3.model.sam3_image_processor import Sam3Processor
# Load the model
model = build_sam3_image_model()
processor = Sam3Processor(model)
# Load an image
annotations_path = "gt_for_classification_multiclass_from_filenames_0_index.csv"
df =pd.read_csv(annotations_path)
for data in df.itertuples():
    if data.category_id != 0:      
        image = Image.open("images\\" + data.file_name)
        inference_state = processor.set_image(image)
        # Prompt the model with text
        output = processor.set_text_prompt(state=inference_state, prompt="medical instrument")
        print(f"Output for {data.file_name}: {output}")
        # Get the masks, bounding boxes, and scores
        masks, boxes, scores = output["masks"], output["boxes"], output["scores"]
        fig, ax = plt.subplots(1)
        ax.imshow(image)

        for box in boxes:
            x1, y1, x2, y2 = box.tolist()
            rect = patches.Rectangle(
                (x1, y1),
                x2 - x1,
                y2 - y1,
                linewidth=2,
                edgecolor="red",
                facecolor="none"
            )
            ax.add_patch(rect)

        plt.title(data.file_name)
        plt.axis("off")
        plt.show(block=False)

        input("Press ENTER to continue to the next image...")
        plt.close(fig)

# %%
import regex as re

df["coordinates"] = pd.Series(dtype="object")

for data in df.itertuples():
    match = re.search(r'\(\s*(\d+)\s*,\s*(\d+)\s*,\s*(\d+)\s*,\s*(\d+)\s*\)', data.answers)
    nums = re.findall(r'\d+', data.answers)
    first_four = nums[:4]
    if match:
        df.at[data.Index, "coordinates"] =  tuple(map(int, match.groups()))#tuple(first_four)
df.to_csv("gt_with_coordinates.csv", index=False)

# %%
import pandas as pd
df= pd.read_csv("gt_with_coordinates.csv")
for data in df.itertuples():
    print(f"{data.answers}: {data.coordinates}")

# %%
for data in df.itertuples():
    if not data.coordinates and data.category_id != 0:
        print(data.answers)

# %%
import cv2
import matplotlib.pyplot as plt
import ast
for _, row in df.iterrows():
    if row["coordinates"] is None:
        continue
    else:
        img_path = "images\\"+row["file_name"]
        try:

            x1, y1, x2, y2 = map(int, ast.literal_eval(row["coordinates"]))
        except (ValueError, TypeError):
            print(f"Error parsing coordinates for {row['file_name']}: {row['coordinates']}")
            continue
        # Load image (BGR → RGB)
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Draw bounding box
        cv2.rectangle(img, (x1, y1), (x2, y2), color=(255, 0, 0), thickness=2)

        # Show image
        cv2.imshow("Image", img)

        key = cv2.waitKey(0)  # wait indefinitely for a key press

        cv2.destroyAllWindows()  # close the image window

        if key == ord('q'):
            break

# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
import re

# Parse coordinates from response
#coordinates_str = response.choices[0].message.content
#coords_match = re.search(r'\((\d+),\s*(\d+),\s*(\d+),\s*(\d+)\)', coordinates_str)
#if coords_match:
#    x1, y1, x2, y2 = map(int, coords_match.groups())
#else:
a= [("b00_i02_a02_20240813_175809_left_0005.jpg", (332, 3, 636, 283)),
("b01_i02_a03_20240815_145236_left_0005.jpg", (0, 236, 455, 421)),
("b01_i02_ablauf_20240815_181417_left_0040.jpg", (417, 0, 638, 224)),
("b00_i03_a02_20240814_140455_left_0002.jpg", (0, 186, 243, 332)),
("b01_i02_ablauf_20240815_191823_left_0015.jpg", (348, 0, 638, 219)),
("b01_i03_a03_20240814_164622_left_0011.jpg", (256, 253, 380, 414)),
("b03_i02_ablauf_20240819_151938_left_0047.jpg", (0, 0, 389, 205)),
("b00_i02_a03_20240814_134626_left_0002.jpg", (449, 0, 640, 225)),
("b00_i02_a03_20240813_163834_left_0004.jpg", (0, 0, 486, 257)),
("b01_i03_a03_20240814_164622_left_0007.jpg", (178, 201, 301, 443)),
("b01_i03_a02_20240814_162236_left_0002.jpg", (0, 0, 243, 170)),
("b00_i02_a01_20240813_180825_left_0004.jpg", (302, 0, 374, 268))
]
for imagename,coordinate in a :
    x1, y1, x2, y2 = coordinate
    image_path="images\\" + imagename
    # Load image
    img = Image.open(image_path)

    # Draw box
    draw = ImageDraw.Draw(img)
    draw.rectangle([x1, y1, x2, y2], outline="red", width=3)

    # Display
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
Processing b00_i02_a02_20240813_175809_left_0005.jpg
Processed b00_i02_a02_20240813_175809_left_0005.jpg: (332, 3, 636, 283)
Processing b01_i02_a03_20240815_145236_left_0005.jpg
Processed b01_i02_a03_20240815_145236_left_0005.jpg: (0, 236, 455, 421)
Processing b01_i02_ablauf_20240815_181417_left_0040.jpg
Processed b01_i02_ablauf_20240815_181417_left_0040.jpg: (417, 0, 638, 224)
Processing b00_i03_a02_20240814_140455_left_0002.jpg
Processed b00_i03_a02_20240814_140455_left_0002.jpg: (0, 186, 243, 332)
Processing b01_i02_ablauf_20240815_191823_left_0015.jpg
Processed b01_i02_ablauf_20240815_191823_left_0015.jpg: (348, 0, 638, 219)
Processing b01_i03_a03_20240814_164622_left_0011.jpg
Processed b01_i03_a03_20240814_164622_left_0011.jpg: (256, 253, 380, 414)
Processing b03_i02_ablauf_20240819_151938_left_0047.jpg
Processed b03_i02_ablauf_20240819_151938_left_0047.jpg: (0, 0, 389, 205)
Processing b00_i02_a03_20240814_134626_left_0002.jpg
Processed b00_i02_a03_20240814_134626_left_0002.jpg: (449, 0, 640, 225)
Processing b00_i02_a03_20240813_163834_left_0004.jpg
Processed b00_i02_a03_20240813_163834_left_0004.jpg: (0, 0, 486, 257)
Processing b01_i03_a03_20240814_164622_left_0007.jpg
Processed b01_i03_a03_20240814_164622_left_0007.jpg: (178, 201, 301, 443)
Processing b01_i03_a02_20240814_162236_left_0002.jpg
Processed b01_i03_a02_20240814_162236_left_0002.jpg: (0, 0, 243, 170)
Processing b00_i02_a01_20240813_180825_left_0004.jpg
Processed b00_i02_a01_20240813_180825_left_0004.jpg: (302, 0, 374, 268)
Processing b01_i03_a03_20240814_170937_left_0007.jpg
print(json_data)

# %% [markdown]
# The expected folder structure to train a Yolo Model is:

# %%
YOLO_Project/
│
├── data/                     # Dataset and configuration files
│   ├── images/               # All images (train/validation)
│   │   ├── train/            # Training images
│   │   │   ├── img1.jpg
│   │   │   ├── img2.jpg
│   │   │   └── ...
│   │   └── val/              # Validation images
│   │       ├── img1.jpg
│   │       └── ...
│   │
│   └── labels/               # YOLO labels (bounding boxes)
│       ├── train/            # Training labels (each .txt corresponds to an image)
│       │   ├── img1.txt
│       │   └── ...
│       └── val/              # Validation labels
│           ├── img1.txt
│           └── ...
│
├── yolov5/                   # YOLOv5 repository (if using YOLOv5)
│   └── ...                   # YOLOv5 scripts, config files, etc.
│
├── yolov8/                   # YOLOv8 repository (if using YOLOv8)
│   └── ...                   # YOLOv8 scripts, config files, etc.
│
└── data.yaml                 # YOLO data configuration file (specifies paths, classes, etc.)

# %%
from calendar import c
import os
import json
import random
import shutil
from sklearn.model_selection import train_test_split
import pandas as pd
# Paths to your data and annotations
images_dir = "images"
annotations_path = "annotations_0_index.json"
output_dir = "yolo_training"

images_output_train = os.path.join(output_dir, "images/train")
images_output_val = os.path.join(output_dir, "images/val")
labels_output_train = os.path.join(output_dir, "labels/train")
labels_output_val = os.path.join(output_dir, "labels/val")

# Create necessary directories
os.makedirs(images_output_train, exist_ok=True)
os.makedirs(images_output_val, exist_ok=True)
os.makedirs(labels_output_train, exist_ok=True)
os.makedirs(labels_output_val, exist_ok=True)

# Load COCO annotations
with open(annotations_path) as f:
    coco_data = json.load(f)

df= pd.read_csv("gt_with_coordinates.csv")
for data in df.itertuples():
    if data.file_name not in image_filename_list:
        coco_data['images'].append({
            "id": data.Index,
            "file_name": data.file_name,
            "width": 640,
            "height": 480
        })
        if type(data.coordinates) == str:
            x1, y1, x2, y2 = map(int, ast.literal_eval(data.coordinates))
            width = x2 - x1
            height = y2 - y1
            coco_data['annotations'].append({
                "id": len(coco_data['annotations']) + 1,
                "image_id": data.Index,
                "category_id": data.category_id,
                "bbox": [x1, y1, width, height],
                "area": width * height,
                "iscrowd": 0
            })  


# Function to convert COCO bbox to YOLO format
def coco_to_yolo(bbox, img_width, img_height):
    x_min, y_min, width, height = bbox
    x_center = (x_min + width / 2) / img_width
    y_center = (y_min + height / 2) / img_height
    width /= img_width
    height /= img_height
    return x_center, y_center, width, height

# Split images into train and val
image_files = [img['file_name'] for img in coco_data['images']]

train_files, val_files = train_test_split(image_files, test_size=0.2, random_state=42)

# Create dictionaries to quickly access image information
image_dict = {img['id']: img for img in coco_data['images']}
annotations_dict = {}
for annotation in coco_data['annotations']:
    image_id = annotation['image_id']
    if image_id not in annotations_dict:
        annotations_dict[image_id] = []
    annotations_dict[image_id].append(annotation)

# Process images and annotations
for img_file in coco_data['images']:
    img_id = img_file['id']
    img_name = img_file['file_name']
    img_width = img_file['width']
    img_height = img_file['height']

    # Determine if the image is in train or val split
    if img_name in train_files:
        img_dest = os.path.join(images_output_train, os.path.basename(img_name))
        label_dest = os.path.join(labels_output_train, os.path.basename(img_name).replace(".jpg", ".txt"))
    else:
        img_dest = os.path.join(images_output_val, os.path.basename(img_name))
        label_dest = os.path.join(labels_output_val, os.path.basename(img_name).replace(".jpg", ".txt"))

    # Copy the image to the corresponding directory
    shutil.copy(os.path.join(images_dir, img_name), img_dest)

    # Write YOLO annotation file
    if img_id in annotations_dict:
        with open(label_dest, 'w') as label_file:
            for annotation in annotations_dict[img_id]:
                category_id = annotation['category_id']
                bbox = annotation['bbox']
                x_center, y_center, width, height = coco_to_yolo(bbox, img_width, img_height)
                label_file.write(f"{category_id} {x_center} {y_center} {width} {height}\n")
            
print("Dataset preparation complete!")

# %% [markdown]
# # Create the needed data.yaml file

# %%
import yaml

# Create the needed data.yaml file

OUTPUT_YAML_DIR = "yolo_training"

data_yaml = {
    "train": images_output_train,
    "val": images_output_val,
    "nc": len(coco_data['categories']),
    "names": [cat['name'] for cat in coco_data['categories']]
}

# Save the data.yaml file
with open(os.path.join(OUTPUT_YAML_DIR, "data.yaml"), 'w') as f:
    yaml.dump(data_yaml, f)

# %% [markdown]
# # Clone the Yolov5 Repo

# %% [markdown]
# ### Clone the repo into the /yolo_training folder via

# %%
cd yolo_training # Adapt to your directory structre
git clone https://github.com/ultralytics/yolov5.git
cd yolov5
pip install -r requirements.txt

# %% [markdown]
# ### Start Training

# %%
cd C:\Users\johan\OneDrive\Desktop\ISM_Project_Group_2\phase_2a\yolo_training\yolov5
# Adapt the /path/to/data.yaml to the path of your data.yaml file
python train.py --img 640 --batch 8 --epochs 200 --data ../data.yaml --cfg models/yolov5m.yaml --weights yolov5m.pt --name instrument_detection

# %% [markdown]
# # Prepare your Submission with script.py

# %% [markdown]
# 1. Copy the yolov5 folder under yolo_training/yolov5 into the /submission/ folder
# 2. Delete the __pycache__/ folder and/or other unnecessary folders to have <250 overall files in the yolov5 folder (>250 files per folder makes uploading to your huggingFace model repo for submission difficult)
# 3. Now you can upload the content of submission/ folder to your HuggingFace Model Repo for submission
